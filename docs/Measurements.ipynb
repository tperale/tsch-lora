# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.style.reload_library()
plt.style.use(['science', 'ieee'])

# %%
data = pd.read_csv("ttj.csv")
drift = pd.read_csv("dm.csv")

# %%
p = data.boxplot(showfliers=False)
p.set_xlabel("Channel number")
p.set_ylabel("EB Cycles")
p
# Out:
# <AxesSubplot:xlabel='Channel number', ylabel='EB Cycles'>

# %%
p = drift['DR'].hist(bins=20, color='grey', weights=np.ones_like(drift[drift.columns[0]]) * 100. / len(drift))
p.set_ylabel("Occurance (\%)")
p.set_xlabel("Drift ($\mu s$)")
p
# Out:
# <AxesSubplot:xlabel='Drift ($\\mu s$)', ylabel='Occurance (\\%)'>
